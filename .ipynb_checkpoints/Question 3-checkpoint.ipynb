# %% [markdown]
# # Question 3.
# The dataset Boston from the library MASS consists of 506 median prices of owner-occupoed homes in $1000s (medv) in various places in Boston. Alongside with price, the dataset also provide various geographic and socio-economic information such as:
#
# - crim -- per capita crime rate by town
# - zn -- proportion of residential land zoned for lots over 25,000 sq.ft
# - indus -- proportion of non-retail business acres per town
# - chas -- Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
# - nox -- nitrogen oxides concentration (parts per 10 million)
# - rm -- average number of rooms per dwelling
# - age -- proportion of owner-occupied units built prior to 1940
# - dis -- weighted mean of distances to five Boston employment centres
# - rad -- index of accessibility to radial highways
# - tax -- full-value property-tax rate per $10,000
# - ptratio -- pupil-teacher ratio by town
# - black -- 1000(Bk−0.63)^2 where Bk is the proportion of blacks by town
# - lstat -- lower status of the population (percent)
#
# The goal is to find the relations between these factors and the house prices.
# 1. Analyze the data to get some first impressions and make some preliminary comments.
# 2. Split randomly (why?) the data into a training and test sets of 80% and 20% of the data respectively. Put a test set meanwhile aside and consider a training set:
#     1. Start from the main effects model, verify its adecuacy.
#     2. If you're not satisfied, try to add paired interactions, perform transformations if necessary.
#     3. Perform model selection w.r.t. various model selection criteria. Compare the resulting models and comment the results.
# 3. Test and compare the goodness-of-fit of those models on the test set. Comment the results, choose the 'final' model and explain it.

# %%
library(MASS)
attach(Boston)
boston = as.data.frame(Boston)
boston$chas = as.factor(boston$chas)

# %% [markdown]
# ## Analyze the data to get some first impressions and make some preliminary comments.

# %% [markdown]
# ### Correlation matrix

# %%
library(corrplot)

corr_matrix<-cor(Boston)
options(repr.plot.width=7, repr.plot.height=7)
corrplot(corr_matrix, type="upper", method = "number")
# Out:
# Warning message:
# "package 'corrplot' was built under R version 3.6.3"corrplot 0.84 loaded
# Plot with title ""

# %% [markdown]
# #### From the correlation matrix:
#
# 1. Median value of owner-occupied homes (**mdev**)
#     - Increases as average number of rooms per dwelling (**rm**) increases
#             A house with more rooms is usually more expensive
#     - Decreases as percent of lower status population (**lstat**) in the area increases
#             Houses are cheaper when there are more people that
#             cannot afford an expensive house (no demand for expensive huses)
# 2. Full-value property-tax rate (**tax**)
#     - Increases as index of accessibility to radial highways (**rad**) increases
#             Access to more highways raises the taxes which make sense because
#             the municipality is investing more money (in higeways) in this area
#     - Increases as proportion of non-retail business acres per town (**indus**) increases
#             Maybe more businesses needs more maintenence (cleaning, infrastructure, etc..)
#             by the municipality, so it needs more money
# 3. Weighted mean of distances to five Boston employment centres (**dis**)
#     - Decreases as proportion of non-retail business acres per town (**indus**) increases
#             There are more non-retail business as you get closer to commercial centers
#     - Decreases as nitrogen oxides concentration (**nox**) (Air pollution) increases
#             There is more nitrogen oxides (air pollution) as you get closer to commercial centers
#     - Decreases as proportion of owner-occupied units built prior to 1940 (**age**) increases
#             Probably new business owners prefered to open their businesses in areas that
#             was already assosiated as commercial centers (because the old businesses)
# 4. Nitrogen oxides concentration (**nox**) (Air pollution)
#     - Increases as proportion of non-retail business acres per town (**indus**)
#             There is more nitrogen oxides (air pollution) as you get closer to commercial centers
#     - Increases as proportion of owner-occupied units built prior to 1940 (**age**)
#             There are more commercial centers around old businneses (which we saw in the previous point)
#             so there are more air pollution

# %% [markdown]
# ### Median value of owner-occupied homes to the explenatory variables plots

# %%
# Define color for each of the 2 categories
colors <- c("Red", "Blue")
colors <- colors[boston$chas]

# Define shapes
shapes = c('+', '*') 
shapes <- shapes[boston$chas]

options(repr.plot.width=10, repr.plot.height=3.33*4)
par(mfrow = c(4,3))
plot(medv ~ crim, data = boston, col=colors, pch=shapes)
plot(medv ~ zn, data = boston, col=colors, pch=shapes)
plot(medv ~ indus, data = boston, col=colors, pch=shapes)
# plot(medv ~ chas, data = boston, col=colors, pch=shapes)
plot(medv ~ nox, data = boston, col=colors, pch=shapes)
plot(medv ~ rm, data = boston, col=colors, pch=shapes)
plot(medv ~ age, data = boston, col=colors, pch=shapes)
plot(medv ~ dis, data = boston, col=colors, pch=shapes)
plot(medv ~ rad, data = boston, col=colors, pch=shapes)
plot(medv ~ tax, data = boston, col=colors, pch=shapes)
plot(medv ~ ptratio, data = boston, col=colors, pch=shapes)
plot(medv ~ black, data = boston, col=colors, pch=shapes)
plot(medv ~ lstat, data = boston, col=colors, pch=shapes)
# Out:
# plot without title

# %% [markdown]
# #### From the plots
# 1. Seems like there are more crime in areas with lower median value of owner-occupied homes (**medv**)
# 2. We can see the good relation between **medv** to the explenatory variables **lstat** and **rm** as presented in the correlation matrix section
# 3. Seems like there are more cheaper houses in areas with a lot of owner-occupied units built prior to 1940 (**age**), probably because there are more old areas among those areas
# 4. Seems like most of the samples are from areas with low black ratio (black is between 300 and 400 when bk is between 0 and 0.08)

# %% [markdown]
# ## Split randomly (why?) the data into a training and test sets of 80% and 20% of the data respectively.
# - Put a test set meanwhile aside and consider a training set

# %% [markdown]
# We split the data randomly because we don't want to train only on certain types of samples and not see at all the other types - overfitting

# %%
set.seed(123)
train.indexes <- sample(nrow(boston), nrow(boston) * 0.80)
boston.train <- boston[train.indexes, ]
boston.test <- boston[-train.indexes, ]

# %% [markdown]
# ### Start from the main effects model, verify its adecuacy.

# %%
lm.maineffects.fit <- lm(medv ~ ., data = boston.train)
# summary(lm.maineffects.fit)

options(repr.plot.width=10, repr.plot.height=5)
par(mfrow = c(1,2))
plot(lm.maineffects.fit, which = 1:2)
# Out:
# Plot with title ""

# %% [markdown]
# #### Main effect model
# 1. All the explenatory variables are significant except **age** and **indus**, but we know that these variables are higly correlated with each other and other variables such as **nox** amd **dis**
# 2. R squared is not very good but fair (0.7441)
# 3. From the residuals vs fitted plot:
#     - The residuals assumtions are clearly not met
#     - The square trend maybe hints that we forgot an explanatory variable (interaction? squared variable?)
#     - We may need a transformation for the X-es
# 4. From the Q-Q plot:
#     - Seems like the residuals distribution has a "shorter" right tail which means the variance equality assumtion is not met

# %% [markdown]
# ### If you're not satisfied, try to add paired interactions, perform transformations if necessary.

# %%
lm.pairedint.fit <- lm(medv ~ .^2, data = boston.train)
# summary(lm.pairedint.fit)

options(repr.plot.width=10, repr.plot.height=5)
par(mfrow = c(1,2))
plot(lm.pairedint.fit, which = 1:2)
# Out:
# Plot with title ""

# %% [markdown]
# #### Main effect and all the paired interactions model
# 1. Now most of the variables are not significant which is not supprosing since they are higly correlated
# 2. R squared is amazing (0.9227) which is also not supprosing since we added **A LOT** of explanatory variables
# 3. From the residuals vs fitted plot:
#     - Much better now, not perfect but fair
#     - We may have few outliers (i.e sample 372), we'll check for outliers with a smaller model
#     - There is sort of monotone trend
#     - Seems like the variance is a function of X $\sigma^2 = \sigma^2(x)$
# 4. From the Q-Q plot:
#     - Also better
#     - Also here sample 372 is looking like an outlier
#     - Now, except sample 372, it seems like the residuals has a "shorter" distribution (compared to standart normal distribution), somthig like t-distribution with few degrees of freedom
#
# Lets give a chance for a transformation

# %% [markdown]
# #### X-es transformation
# - Let's plot again the explanatory variables against the dependant variable and try to find transformations
# - We'll plot **medv** on x axis for convinience

# %%
options(repr.plot.width=10, repr.plot.height=3.33*4)
par(mfrow = c(4,3))
plot(crim ~ medv, data = boston, col=colors, pch=shapes)
plot(zn ~ medv, data = boston, col=colors, pch=shapes)
plot(indus ~ medv, data = boston, col=colors, pch=shapes)
plot(nox ~ medv, data = boston, col=colors, pch=shapes)
plot(rm ~ medv, data = boston, col=colors, pch=shapes)
plot(age ~ medv, data = boston, col=colors, pch=shapes)
plot(dis ~ medv, data = boston, col=colors, pch=shapes)
plot(rad ~ medv, data = boston, col=colors, pch=shapes)
plot(tax ~ medv, data = boston, col=colors, pch=shapes)
plot(ptratio ~ medv, data = boston, col=colors, pch=shapes)
plot(black ~ medv, data = boston, col=colors, pch=shapes)
plot(lstat ~ medv, data = boston, col=colors, pch=shapes)
# Out:
# plot without title

# %% [markdown]
# ##### X transformation candidates:
# 1. **crime** to log(crime)
# 2. **indus** to log(indus)
# 3. **dis** to 1/dis
# 4. **tax** to log(tax)
# 5. **lstat** to log(lstat)
#
# See below, **the left columd is before and the right colums is after**

# %%
options(repr.plot.width=8, repr.plot.height=4*4)
par(mfrow = c(5,2))
plot(crim ~ medv, data = boston, col=colors, pch=shapes)
plot(log(crim) ~ medv, data = boston, col=colors, pch=shapes)

plot(indus ~ medv, data = boston, col=colors, pch=shapes)
plot(log(indus) ~ medv, data = boston, col=colors, pch=shapes)


plot(dis ~ medv, data = boston, col=colors, pch=shapes)
plot(1/dis ~ medv, data = boston, col=colors, pch=shapes)

plot(tax ~ medv, data = boston, col=colors, pch=shapes)
plot(log(tax) ~ medv, data = boston, col=colors, pch=shapes)

plot(lstat ~ medv, data = boston, col=colors, pch=shapes)
plot(log(lstat) ~ medv, data = boston, col=colors, pch=shapes)

mtext("Before transformation", side = 3, line = -3, outer = TRUE, adj = 0)
mtext("After transformation", side = 3, line = -3, outer = TRUE, adj = 1)
# Out:
# plot without title

# %% [markdown]
# ##### Main effect model with the X-transformations

# %%
lm.maineffects.xtrans.fit <- lm(medv ~ log(crim) + zn + log(indus) + nox + rm + age + 1/dis + rad + log(tax) + ptratio + black + log(lstat), data = boston.train)
summary(lm.maineffects.xtrans.fit)

options(repr.plot.width=10, repr.plot.height=5)
par(mfrow = c(1,2))
plot(lm.maineffects.xtrans.fit, which = 1:2)
# Out:
# Call:
# lm(formula = medv ~ log(crim) + zn + log(indus) + nox + rm +
#     age + 1/dis + rad + log(tax) + ptratio + black + log(lstat),
#     data = boston.train)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -11.2468  -2.5879  -0.4294   2.0834  26.5989
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  70.251612   8.653481   8.118 6.19e-15 ***
# log(crim)     0.140650   0.297380   0.473 0.636502
# zn           -0.010184   0.014510  -0.702 0.483177
# log(indus)    0.301279   0.563201   0.535 0.592994
# nox          -8.076139   3.906058  -2.068 0.039334 *
# rm            2.286250   0.461289   4.956 1.07e-06 ***
# age           0.065537   0.013718   4.777 2.51e-06 ***
# rad           0.202849   0.067833   2.990 0.002962 **
# log(tax)     -4.272070   1.285581  -3.323 0.000974 ***
# ptratio      -0.941770   0.136985  -6.875 2.45e-11 ***
# black         0.008334   0.003004   2.775 0.005792 **
# ...

# %% [markdown]
# ##### Main effect model with x-transformations - summary
# 1. R squared is better (0.771) compared to the main effects model without the X-transformations (0.7441)
# 2. From the residuals vs fitted plot:
#     - The residuals assumtions yet not met
#     - The square trend is looking lighter but we missing an explanatory variable (interaction?)

# %% [markdown]
# ##### Main effect and all the paired interactions model with x-transformations

# %%
lm.pairedint.xtrans.fit <- lm(medv ~ (log(crim) + zn + log(indus) + nox + rm + age + 1/dis + rad + log(tax) + ptratio + black + log(lstat))^2, data = boston.train)
summary(lm.pairedint.xtrans.fit)

options(repr.plot.width=10, repr.plot.height=5)
par(mfrow = c(1,2))
plot(lm.pairedint.xtrans.fit, which = 1:2)
# Out:
# Call:
# lm(formula = medv ~ (log(crim) + zn + log(indus) + nox + rm +
#     age + 1/dis + rad + log(tax) + ptratio + black + log(lstat))^2,
#     data = boston.train)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -7.6060 -1.5349 -0.1451  1.4014 22.3440
#
# Coefficients:
#                         Estimate Std. Error t value Pr(>|t|)
# (Intercept)            1.119e+02  2.790e+02   0.401 0.688776
# log(crim)             -2.284e+01  1.165e+01  -1.960 0.050771 .
# zn                    -1.135e+00  6.585e-01  -1.724 0.085562 .
# log(indus)            -2.913e+01  2.619e+01  -1.112 0.266750
# nox                    4.898e+01  2.273e+02   0.215 0.829561
# rm                     2.382e+01  2.169e+01   1.098 0.272927
# age                    1.230e+00  5.401e-01   2.278 0.023350 *
# rad                    5.027e+00  3.069e+00   1.638 0.102337
# log(tax)              -3.709e+01  5.528e+01  -0.671 0.502695
# ptratio               -1.217e+01  5.635e+00  -2.159 0.031535 *
# ...

# %% [markdown]
# ##### Main effect and all the paired interactions model with x-transformations - summary
# 1. R squared (0.9068) is lower than the R squared in the paired interactions model (0.9227)
# 3. From the residuals vs fitted plot:
#     - The residuals are better!
# 4. From the Q-Q plot:
#     - Also better!
#
# Lets try to improve this with a boxcox transformation

# %% [markdown]
# ##### Main effect and all the paired interactions model with both, y and x transformations

# %%
options(repr.plot.width=5, repr.plot.height=4)
par(mfrow = c(1,1))
lamb = boxcox(lm.pairedint.xtrans.fit, lambda = seq(0, 1, 1/10), plotit = TRUE, eps = 1/50, xlab = expression(lambda), ylab = "log-Likelihood")
# Out:
# plot without title

# %% [markdown]
# By Box-cox, a cube root reansformation to the response variable will be appropriate

# %%
lm.pairedint.xytrans.fit <- lm(sqrt(medv) ~ (log(crim) + zn + log(indus) + nox + rm + age + 1/dis + rad + log(tax) + ptratio + black + log(lstat))^2, data = boston.train)
summary(lm.pairedint.xytrans.fit)

options(repr.plot.width=10, repr.plot.height=5)
par(mfrow = c(1,2))
plot(lm.pairedint.xytrans.fit, which = 1:2)
# Out:
# Call:
# lm(formula = sqrt(medv) ~ (log(crim) + zn + log(indus) + nox +
#     rm + age + 1/dis + rad + log(tax) + ptratio + black + log(lstat))^2,
#     data = boston.train)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.85664 -0.16973 -0.00881  0.14972  1.98650
#
# Coefficients:
#                         Estimate Std. Error t value Pr(>|t|)
# (Intercept)            2.792e+01  2.829e+01   0.987 0.324441
# log(crim)             -1.965e+00  1.181e+00  -1.664 0.097098 .
# zn                    -1.018e-01  6.677e-02  -1.525 0.128299
# log(indus)            -3.031e+00  2.655e+00  -1.141 0.254538
# nox                    1.588e+00  2.305e+01   0.069 0.945123
# rm                     1.344e+00  2.200e+00   0.611 0.541478
# age                    1.310e-01  5.476e-02   2.393 0.017281 *
# rad                    4.963e-01  3.111e-01   1.595 0.111632
# log(tax)              -5.111e+00  5.605e+00  -0.912 0.362457
# ...

# %% [markdown]
# ##### Main effect and all the paired interactions model with both, y and x transformations - summary
# 1. R squared (0.9081) is a bit better compared to the model without the y transformation (0.9068)
# 3. From the residuals vs fitted plot:
#     - The residuals are even better!
# 4. From the Q-Q plot:
#     - Also better!

# %% [markdown]
# #### Compare the models we have so far

# %%
crossVal <- function(lm.object)
{
    # Computes the cross-validation (CV), the generalized cross-validation (GCV) and the cross-validation correlation coefficient (R^2_{CV}) for the specified linear model
    res <- lm.object$residuals
    y <- lm.object$fitted.values + lm.object$residuals
    h <- lm.influence(lm.object)$hat
    n <- length(y)
    cv <- mean(res^2/(1 - h)^2)
    gcv <- (n * sum(res^2))/lm.object$df^2
    r2cv <- cor(y, y - res/(1 - h))^2
    return(cbind(cv, gcv, r2cv))
}

# %%
none <- function(x){ return (x)}

mspe <- function(lm.object, un.trans = none, newdata = boston.test, ...){
    pred.test <- un.trans(predict(lm.object, newdata, ...))
    mspe <- mean((pred.test - boston.test$medv) ^ 2)
    
    return (cbind(mspe))
}

# %%
lm.maineffects.fit.crossVal <- crossVal(lm.maineffects.fit)
lm.maineffects.xtrans.fit.crossVal <- crossVal(lm.maineffects.xtrans.fit)
lm.pairedint.fit.crossVal <- crossVal(lm.pairedint.fit)
lm.pairedint.xtrans.fit.crossVal <- crossVal(lm.pairedint.xtrans.fit)
lm.pairedint.xytrans.fit.crossVal <- crossVal(lm.pairedint.xytrans.fit)
models <- c("Main effects", "Main effects with x trans", "Paired interactions", "Paired interactions with x trans", "Paired interactions with both, x and y trans")

results <- cbind(models,
                 rbind(lm.maineffects.fit.crossVal, 
                       lm.maineffects.xtrans.fit.crossVal, 
                       lm.pairedint.fit.crossVal, 
                       lm.pairedint.xtrans.fit.crossVal, 
                       lm.pairedint.xytrans.fit.crossVal))

# %%
lm.maineffects.fit.mspe <- mspe(lm.maineffects.fit)
lm.maineffects.xtrans.fit.mspe <- mspe(lm.maineffects.xtrans.fit)
lm.pairedint.fit.mspe <- mspe(lm.pairedint.fit)
lm.pairedint.xtrans.fit.mspe <- mspe(lm.pairedint.xtrans.fit)

quad <- function(x){ return(x^2)}
lm.pairedint.xytrans.fit.mspe <- mspe(lm.pairedint.xytrans.fit, un.trans = quad)

results <- cbind(results, 
     rbind(lm.maineffects.fit.mspe, 
           lm.maineffects.xtrans.fit.mspe,
           lm.pairedint.fit.mspe,
           lm.pairedint.xtrans.fit.mspe,
           lm.pairedint.xytrans.fit.mspe))
results
# Out:
#      models                                       cv
# [1,] Main effects                                 23.8817957015301
# [2,] Main effects with x trans                    20.8631496795912
# [3,] Paired interactions                          13.587450214699
# [4,] Paired interactions with x trans             11.1923264628084
# [5,] Paired interactions with both, x and y trans 0.115871554479785
#      gcv               r2cv              mspe
# [1,] 23.1879903498101  0.717412897833394 23.6786297152814
# [2,] 20.5341214420344  0.752973929160763 22.6872189411733
# [3,] 10.9423298141657  0.842983771867659 10.3335236625828
# [4,] 11.3087068462525  0.86825677166949  12.3163129334912
# [5,] 0.116257505165231 0.869501791602453 12.7635106504784

# %% [markdown]
# #### Compare the models we have so far - summary
# 1. We cannot compare all the models using cv/gcv because of the y transformation
# 2. By the r2cv, the last model with the paired interactions and both x & y transformations is a bit better
# 3. By mspe, the model with the paird interactions and without the transformations is the winner

# %%
# cooksd <- cooks.distance(lm.pairedint.xtrans.fit)
# sample_size <- nrow(boston.train)

# # influential row numbers
# influential <- as.numeric(names(cooksd)[(cooksd > (4/sample_size))])

# # Removing Outliers
# data_screen <- boston.train[-influential, ]

# cat("influential: ", influential)

# %% [markdown]
# ### Perform model selection w.r.t. various model selection criteria.
# - Compare the resulting models and comment the results.

# %% [markdown]
# #### AIC, BIC & RIC

# %%
mod.aic <- stepAIC(lm.pairedint.fit,
                   scope=list(upper= medv ~ .^2, lower= ~1), 
                   direction = "both",
                   trace=F,
                   k=2)
# summary(mod.aic)

# %%
n=nrow(boston.train)

mod.bic <- stepAIC(lm.pairedint.fit,
                   scope=list(upper= medv ~ .^2, lower= ~1), 
                   direction = "both",
                   trace=F,
                   k=log(n))
# summary(mod.bic)

# %%
p=length(lm.pairedint.fit$coefficients)-1

mod.ric <- stepAIC(lm.pairedint.fit,
                   scope=list(upper= medv ~ .^2, lower= ~1), 
                   direction = "both",
                   trace=F,
                   k=2*log(p))
# summary(mod.ric)

# %%
# print(anova(lm.pairedint.fit, mod.aic))
# print(anova(lm.pairedint.fit, mod.bic))
# print(anova(lm.pairedint.fit, mod.ric))

# %%
mod.aic.crossVal <- crossVal(mod.aic)
mod.bic.crossVal <- crossVal(mod.bic)
mod.ric.crossVal <- crossVal(mod.ric)

models <- c("AIC", "BIC", "RIC")

step_results <- cbind(models,
                 rbind(mod.aic.crossVal, 
                       mod.bic.crossVal, 
                       mod.ric.crossVal))

mod.aic.mspe <- mspe(mod.aic)
mod.bic.mspe <- mspe(mod.bic)
mod.ric.mspe <- mspe(mod.ric)

step_results <- cbind(step_results, 
     rbind(mod.aic.mspe, 
           mod.bic.mspe,
           mod.ric.mspe))

rbind(results, step_results)
# Out:
#      models                                       cv
# [1,] Main effects                                 23.8817957015301
# [2,] Main effects with x trans                    20.8631496795912
# [3,] Paired interactions                          13.587450214699
# [4,] Paired interactions with x trans             11.1923264628084
# [5,] Paired interactions with both, x and y trans 0.115871554479785
# [6,] AIC                                          6.98019580624369
# [7,] BIC                                          7.65040989796025
# [8,] RIC                                          9.64678396282551
#      gcv               r2cv              mspe
# [1,] 23.1879903498101  0.717412897833394 23.6786297152814
# [2,] 20.5341214420344  0.752973929160763 22.6872189411733
# [3,] 10.9423298141657  0.842983771867659 10.3335236625828
# [4,] 11.3087068462525  0.86825677166949  12.3163129334912
# [5,] 0.116257505165231 0.869501791602453 12.7635106504784
# ...

# %% [markdown]
# #### Lasso
# - starting from the model with all the paired interactions

# %%
library(glmnet)

X.lasso <- model.matrix(lm.pairedint.fit)

mod.lasso0.cv <- cv.glmnet(X.lasso,
                           boston.train$medv,alpha=1,
                           nfolds=nrow(X.lasso), #Choose lambda using LOO CV
                           grouped=FALSE)

options(repr.plot.width=5, repr.plot.height=4)
plot(mod.lasso0.cv)
# Out:
# plot without title

# %%
mod.lasso <- glmnet(X.lasso, boston.train$medv,alpha=1,lambda=mod.lasso0.cv$lambda.min)
# print(round(predict(mod.lasso,s=mod.lasso0.cv$lambda.min,type="coefficients"),5))

# %%
#calculate lasso CV
lambda.cv.index = which(mod.lasso0.cv$lambda == mod.lasso0.cv$lambda.min)
mod.lasso.cv = mod.lasso0.cv$cvm[lambda.cv.index][[1]]

#calculate lasso GCV
mod.lasso.rss = sum((predict(mod.lasso, model.matrix(lm.pairedint.fit)) - boston.train$medv)^2)
n = nrow(X.lasso)
p = ncol(X.lasso)
mod.lasso.gcv = (n/(n-p)^2)*mod.lasso.rss

#calculate lasso R2CV
mod.lasso.cv.pred <- lapply(1:nrow(X.lasso), function(i){
    fit <- glmnet(as.matrix(X.lasso[-i,]),
                boston.train$medv[-i],
                alpha = 1,
                lambda = mod.lasso0.cv$lambda.min)
    pred <- predict(fit, t(X.lasso[i,]))[1]

    return(pred)
})
mod.lasso.r2cv = cor(boston.train$medv, as.numeric(mod.lasso.cv.pred))^2

#calculate lasso MSPE
newx <- model.matrix(as.formula(medv ~ .^2), boston.test)
mod.lasso.mspe <- mspe(mod.lasso, newdata = newx)

# %%
lasso_result = cbind("LASSO", mod.lasso.cv, mod.lasso.gcv, mod.lasso.r2cv, mod.lasso.mspe)
rbind(results, step_results, lasso_result)
# Out:
#       models                                       cv
#  [1,] Main effects                                 23.8817957015301
#  [2,] Main effects with x trans                    20.8631496795912
#  [3,] Paired interactions                          13.587450214699
#  [4,] Paired interactions with x trans             11.1923264628084
#  [5,] Paired interactions with both, x and y trans 0.115871554479785
#  [6,] AIC                                          6.98019580624369
#  [7,] BIC                                          7.65040989796025
#  [8,] RIC                                          9.64678396282551
#  [9,] LASSO                                        12.3284790081223
#       gcv               r2cv              mspe
#  [1,] 23.1879903498101  0.717412897833394 23.6786297152814
#  [2,] 20.5341214420344  0.752973929160763 22.6872189411733
#  [3,] 10.9423298141657  0.842983771867659 10.3335236625828
#  [4,] 11.3087068462525  0.86825677166949  12.3163129334912
# ...

# %% [markdown]
# #### PCR & PLS

# %%
pls.crossVal <- function(pls.object, p)
{
    n = nrow(pls.object$fitted.values)
    
    # CV
    cv = pls.object$validation$PRESS[,p]/n

    # GCV
    rss = sum(pls.object$residuals[,,][,p]^2)
    gcv = (n/(n-p)^2)*rss

    # R2CV
    y <- mod.pcr$fitted.values[,,][,p] + mod.pcr$residuals[,,][,p]
    r2cv = cor(y, mod.pcr$validation$pred[,,][,p])^2

    return(cbind(cv, gcv, r2cv))
}

# %%
library(pls)

mod.pcr = pcr(medv ~ .^2, data=boston.train, scale=T, validation="LOO")

# %%
summary(mod.pcr)
# Out:
# Data: 	X dimension: 404 91
# 	Y dimension: 404 1
# Fit method: svdpc
# Number of components considered: 91
#
# VALIDATION: RMSEP
# Cross-validated using 404 leave-one-out segments.
#        (Intercept)  1 comps  2 comps  3 comps  4 comps  5 comps  6 comps
# CV           9.211    7.667     7.47    7.377    7.421    5.558    5.592
# adjCV        9.211    7.667     7.47    7.377    7.421    5.552    5.592
#        7 comps  8 comps  9 comps  10 comps  11 comps  12 comps  13 comps
# CV       5.160     5.11    5.137     5.165     5.113     5.144     5.112
# adjCV    5.159     5.11    5.137     5.165     5.112     5.144     5.112
#        14 comps  15 comps  16 comps  17 comps  18 comps  19 comps  20 comps
# CV        5.157     4.970     4.979     4.838     4.740     4.725     4.732
# adjCV     5.157     4.969     4.978     4.837     4.739     4.724     4.732
#        21 comps  22 comps  23 comps  24 comps  25 comps  26 comps  27 comps
# ...

# %%
options(repr.plot.width=10, repr.plot.height=5)
par(mfrow = c(1,2))
validationplot(mod.pcr, main="All components")
validationplot(mod.pcr, ncomp = 1:20, main="Zoom into the first 20 components")
# Out:
# Plot with title "Zoom into the first 20 components"

# %% [markdown]
# We can see that after the first 5 components, CV has a negligible improvment. 76.54% of the variance in the data is being explained by these 5 first components.
# - Projecting the data on the first 5 eigenvectors will significantly reduce the data dimensions and will explain most of it's variance

# %%
# 5 comp PCR CV, GCV, R2CV
pcr_results <- pls.crossVal(mod.pcr, 8)

# 5 comp PCR MSPE
mod.pcr.mspe <- mspe(mod.pcr, ncomp = 8)

# %%
pcr_results = cbind("PCR - 8 components", pcr_results, mod.pcr.mspe)
rbind(results, step_results, lasso_result, pcr_results)
# Out:
#       models                                       cv
#  [1,] Main effects                                 23.8817957015301
#  [2,] Main effects with x trans                    20.8631496795912
#  [3,] Paired interactions                          13.587450214699
#  [4,] Paired interactions with x trans             11.1923264628084
#  [5,] Paired interactions with both, x and y trans 0.115871554479785
#  [6,] AIC                                          6.98019580624369
#  [7,] BIC                                          7.65040989796025
#  [8,] RIC                                          9.64678396282551
#  [9,] LASSO                                        12.3284790081223
# [10,] PCR - 8 components                           26.1137067643492
#       gcv               r2cv              mspe
#  [1,] 23.1879903498101  0.717412897833394 23.6786297152814
#  [2,] 20.5341214420344  0.752973929160763 22.6872189411733
#  [3,] 10.9423298141657  0.842983771867659 10.3335236625828
# ...

# %% [markdown]
# ##### PCR - Summary
# - PCR is not performing very good.
# - We know there is a problem with modeling the data using PCR such as it doesn't take the response variable (**medv**) in consideration

# %%
mod.pls = plsr(medv ~ .^2, data=boston.train, scale=T, validation="LOO")

# %%
summary(mod.pls)
# Out:
# Data: 	X dimension: 404 91
# 	Y dimension: 404 1
# Fit method: kernelpls
# Number of components considered: 91
#
# VALIDATION: RMSEP
# Cross-validated using 404 leave-one-out segments.
#        (Intercept)  1 comps  2 comps  3 comps  4 comps  5 comps  6 comps
# CV           9.211    7.025    5.365    4.985    4.936    4.826    4.721
# adjCV        9.211    7.025    5.365    4.985    4.936    4.825    4.720
#        7 comps  8 comps  9 comps  10 comps  11 comps  12 comps  13 comps
# CV       4.610    4.519    4.485     4.416     4.481     4.294     4.293
# adjCV    4.609    4.519    4.486     4.416     4.481     4.292     4.291
#        14 comps  15 comps  16 comps  17 comps  18 comps  19 comps  20 comps
# CV        4.183     4.153     4.137     4.019     4.061     4.028     4.006
# adjCV     4.181     4.152     4.136     4.018     4.059     4.026     4.005
#        21 comps  22 comps  23 comps  24 comps  25 comps  26 comps  27 comps
# ...

# %%
options(repr.plot.width=10, repr.plot.height=5)
par(mfrow = c(1,2))
validationplot(mod.pls, main="All components")
validationplot(mod.pls, ncomp = 1:20, main="Zoom into the first 20 components")
# Out:
# Plot with title "Zoom into the first 20 components"

# %% [markdown]
# We can see that after the first 5 components, CV has a negligible improvment. 76.54% of the variance in the data is being explained by these 5 first components.
# - Projecting the data on the first 5 eigenvectors will significantly reduce the data dimensions and will explain most of it's variance

# %%
# 5 comp PCR CV, GCV, R2CV
pls_results <- pls.crossVal(mod.pls, 10)

# 5 comp PCR MSPE
mod.pls.mspe <- mspe(mod.pcr, ncomp = 10)

# %%
pls_results <- cbind("PLS - 10 components", pls_results, mod.pls.mspe)

rbind(results, step_results, lasso_result, pcr_results, pls_results)
# Out:
#       models                                       cv
#  [1,] Main effects                                 23.8817957015301
#  [2,] Main effects with x trans                    20.8631496795912
#  [3,] Paired interactions                          13.587450214699
#  [4,] Paired interactions with x trans             11.1923264628084
#  [5,] Paired interactions with both, x and y trans 0.115871554479785
#  [6,] AIC                                          6.98019580624369
#  [7,] BIC                                          7.65040989796025
#  [8,] RIC                                          9.64678396282551
#  [9,] LASSO                                        12.3284790081223
# [10,] PCR - 8 components                           26.1137067643492
# [11,] PLS - 10 components                          19.504807772412
#       gcv               r2cv              mspe
#  [1,] 23.1879903498101  0.717412897833394 23.6786297152814
#  [2,] 20.5341214420344  0.752973929160763 22.6872189411733
# ...

# %% [markdown]
# ##### PCR - Summary
# - PCR is not performing very good.
# - We know there is a problem with modeling the data using PCR such as it doesn't take the response variable (**medv**) in consideration
